# %%
SI=input(("ENTER SI NO OF CON ROD SET:"))
MAIN=int(input(("ENTER WEIGHT OF MAIN CONNECTING ROD WITHIN 5600+50 OR 5600-50 GMS:")))
ARTI=int(input(("ENTER WEIGHT OF ARTICULATED CONNECTING ROD WITHIN 2140+20 OR 2140-20 GMS:")))
TOTAL_1=MAIN+ARTI
print(TOTAL_1)
PISTONASSYLH=int(input("ENTER WEIFHT OF PISTON ASSY LH(3060+30 OR 3060-30 ) VARIATION SHOULD NOT EXCEED 5GMS:"))
PISTONASSYRH=int(input("ENTER WEIFHT OF PISTON ASSY RH(3060+30 OR 3060-30 ) VARIATION SHOULD NOT EXCEED 5GMS:"))
TOTAL_2=MAIN+PISTONASSYLH
print(TOTAL_2)
TOTAL_3=ARTI+PISTONASSYRH
print(TOTAL_3)
TOTALWEIGHTOFCONRODPISTONLHRH=TOTAL_2+TOTAL_3
print("TOTAL WEIGHT OF CON ROD PISTON LH RH:",TOTALWEIGHTOFCONRODPISTONLHRH)
# Out:
# ENTER SI NO OF CON ROD SET: M842/26
# ENTER WEIGHT OF MAIN CONNECTING ROD WITHIN 5600+50 OR 5600-50 GMS: 5638
# ENTER WEIGHT OF ARTICULATED CONNECTING ROD WITHIN 2140+20 OR 2140-20 GMS: 2156
# 7794
# ENTER WEIFHT OF PISTON ASSY LH(3060+30 OR 3060-30 ) VARIATION SHOULD NOT EXCEED 5GMS: 3074
# ENTER WEIFHT OF PISTON ASSY RH(3060+30 OR 3060-30 ) VARIATION SHOULD NOT EXCEED 5GMS: 3076
# 8712
# 5232
# TOTAL WEIGHT OF CON ROD PISTON LH RH: 13944
